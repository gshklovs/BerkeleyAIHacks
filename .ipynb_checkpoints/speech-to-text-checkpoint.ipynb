# %%
import os
import sounddevice as sd
import numpy as np
from pydub import AudioSegment
from groq import Groq


def install_dependencies():
    os.system("pip install sounddevice pydub groq")


def record_audio(seconds):
    print("Recording audio...")
    fs = 44100  # Sample rate
    duration = seconds  # Duration in seconds
    recording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype=np.int16)
    sd.wait()  # Wait until recording is finished
    print("Recording finished.")
    return recording, fs


def append_silence(recording, seconds_to_append, sample_rate):
    print(f"Appending {seconds_to_append} seconds of silence...")
    # Create a silence array with the same number of channels as the recording
    silence = np.zeros(
        (int(seconds_to_append * sample_rate), recording.shape[1]), dtype=np.int16
    )
    return np.concatenate((recording, silence))


def save_to_m4a(audio_data, sample_rate, filename):
    # Convert numpy array to AudioSegment
    audio = AudioSegment(
        audio_data.tobytes(),
        frame_rate=sample_rate,
        sample_width=audio_data.dtype.itemsize,
        channels=1,
    )

    # Export as M4A
    audio.export(filename, format="mp3")


def perform_transcription(filename):
    client = Groq(api_key="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")
    with open(filename, "rb") as file:
        transcription = client.audio.transcriptions.create(
            file=(filename, file.read()),
            model="whisper-large-v3",
            prompt="Specify context or spelling",  # Optional
            response_format="json",  # Optional
            language="en",  # Optional
            temperature=0.0,  # Optional
        )
    return transcription.text


def make_sample():
    # Record audio for 10 seconds
    audio_data, sample_rate = record_audio(10)
    # Append 20 seconds of silence to the recorded audio
    audio_data = append_silence(audio_data, 20, sample_rate)
    # Save the recorded audio to an M4A file
    filename = "./sample.m4a"
    save_to_m4a(audio_data, sample_rate, filename)
    print(f"Sample audio saved to {filename}")
    return filename


def main():
    filename = make_sample()
    # Perform transcription using Groq API
    transcription_text = perform_transcription(filename)
    print("Transcription Result:")
    print(transcription_text)


if __name__ == "__main__":
    # install_dependencies()
    main()
# Out:
# Requirement already satisfied: sounddevice in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (0.4.7)
# Requirement already satisfied: pydub in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (0.25.1)
# Requirement already satisfied: groq in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: CFFI>=1.0 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from sounddevice) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from groq) (2.7.4)
# Requirement already satisfied: sniffio in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: pycparser in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice) (2.22)
# Requirement already satisfied: certifi in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/grisha/miniconda3/envs/yapper/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq) (2.18.4)
# Recording audio...
# Recording finished.
# Appending 25 seconds of audio...
# Audio saved to ./recorded_audio.m4a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 71
#      69 if __name__ == "__main__":
#      70     install_dependencies()
# ---> 71     main()
#
# Cell In[22], line 65, in main()
#      62 print(f"Audio saved to {filename}")
#      64 # Perform transcription using Groq API
# ---> 65 transcription_text = perform_transcription(filename)
#      66 print("Transcription Result:")
#      67 print(transcription_text)
#
# Cell In[22], line 40, in perform_transcription(filename)
#      39 def perform_transcription(filename):
# ---> 40     client = Groq(api_key=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)
#      41     with open(filename, "rb") as file:
#      42         transcription = client.audio.transcriptions.create(
#      43             file=(filename, file.read()),
#      44             model="whisper-large-v3",
#    (...)
#      48             temperature=0.0  # Optional
#      49         )
#
# NameError: name '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' is not defined
